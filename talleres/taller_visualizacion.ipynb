# %% [markdown]
# # Taller Matplotlib y Seaborn: Visualización de Datos Financieros
#
# ## Objetivo
# Aplicar técnicas de visualización de datos usando Matplotlib y Seaborn sobre el dataset de transacciones bancarias ya limpio.
#
# ## Estructura del Taller
# 1. **Setup y Carga de Datos**
# 2. **Visualizaciones Básicas con Matplotlib**
# 3. **Visualizaciones Estadísticas con Seaborn**
# 4. **Análisis Temporal con Gráficos de Línea**
# 5. **Visualizaciones Comparativas**
# 6. **Dashboard Final (Múltiples Gráficos)**
#
# ## Prerequisitos
# Haber completado el taller de Pandas ETL y tener el archivo `transacciones_bancarias_limpio.csv`

# %% [markdown]
# ---
# ## PARTE 0: SETUP Y CARGA DE DATOS

# %%
# Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración para mejorar visualizaciones
plt.style.use('seaborn-v0_8-darkgrid')  # Estilo de gráficos
sns.set_palette("husl")  # Paleta de colores
# %matplotlib inline

# Configurar tamaño de figura por defecto
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 10

print("✅ Librerías importadas correctamente")

# %%
# Ejercicio 0.1: Cargar el dataset limpio
# TODO: Lee el archivo 'transacciones_bancarias_limpio.csv'
# IMPORTANTE: Este es el resultado del taller anterior de Pandas

df = pd.read_csv('transacciones_bancarias_limpio.csv')

# Convertir la columna fecha a datetime (si no está ya)
df['fecha'] = pd.to_datetime(df['fecha'])

print(f"Dataset cargado: {len(df)} registros")
print(f"Columnas: {df.columns.tolist()}")
df.head()

# %% [markdown]
# ---
# ## PARTE 1: VISUALIZACIONES BÁSICAS CON MATPLOTLIB

# %% [markdown]
# ### 1.1 Gráfico de Barras Simple

# %%
# Ejercicio 1.1: Gráfico de barras - Transacciones por tipo
# TODO: Crea un gráfico de barras que muestre la cantidad de transacciones por tipo
# Pista: 
# 1. Calcula value_counts() de tipo_transaccion
# 2. Usa plt.bar() o el método .plot(kind='bar')
# 3. Agrega título, etiquetas de ejes y rota las etiquetas del eje x

# Tu código aquí
transacciones_tipo = 

plt.figure(figsize=(10, 6))
# Crear gráfico de barras

plt.title('', fontsize=14, fontweight='bold')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Gráfico de Barras Horizontales

# %%
# Ejercicio 1.2: Gráfico de barras horizontales - Top 10 clientes
# TODO: Crea un gráfico de barras HORIZONTALES con los 10 clientes con más transacciones
# Pista: 
# 1. value_counts() de cliente_id y toma los primeros 10 (.head(10))
# 2. Usa plt.barh() o .plot(kind='barh')
# 3. Invierte el orden para que el mayor esté arriba (.iloc[::-1])

# Tu código aquí


plt.title('Top 10 Clientes con Más Transacciones', fontsize=14, fontweight='bold')
plt.xlabel('Cantidad de Transacciones')
plt.ylabel('Cliente ID')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3 Gráfico de Pastel (Pie Chart)

# %%
# Ejercicio 1.3: Gráfico de pastel - Distribución por canal
# TODO: Crea un gráfico de pastel mostrando el % de transacciones por canal
# Pista:
# 1. Calcula value_counts() de 'canal'
# 2. Usa plt.pie() con autopct='%1.1f%%' para mostrar porcentajes
# 3. Agrega startangle=90 para mejor visualización

# Tu código aquí


plt.title('Distribución de Transacciones por Canal', fontsize=14, fontweight='bold')
plt.axis('equal')  # Para que sea un círculo perfecto
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.4 Histograma

# %%
# Ejercicio 1.4: Histograma - Distribución de montos
# TODO: Crea un histograma de la columna 'monto_absoluto'
# Pista:
# 1. Usa plt.hist() con bins=50
# 2. Agrega edgecolor='black' para ver mejor las barras
# 3. Opcional: filtra montos < $5,000,000 para mejor visualización

# Tu código aquí


plt.title('Distribución de Montos de Transacciones', fontsize=14, fontweight='bold')
plt.xlabel('Monto Absoluto ($)')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.5 Scatter Plot (Dispersión)

# %%
# Ejercicio 1.5: Gráfico de dispersión - Monto vs Hora del día
# TODO: Crea un scatter plot para ver si hay relación entre hora y monto
# Pista:
# 1. Extrae la hora de la columna 'hora' (split(':').str[0].astype(int))
# 2. Usa plt.scatter() con alpha=0.3 para ver superposición
# 3. Colorea por 'sospechosa' si quieres (c=df['sospechosa'])

# Tu código aquí
df['hora_num'] = 

plt.figure(figsize=(12, 6))
# Crear scatter plot

plt.title('Relación entre Hora del Día y Monto de Transacción', fontsize=14, fontweight='bold')
plt.xlabel('Hora del Día (0-23)')
plt.ylabel('Monto Absoluto ($)')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## PARTE 2: VISUALIZACIONES ESTADÍSTICAS CON SEABORN

# %% [markdown]
# ### 2.1 Count Plot (Barras con Seaborn)

# %%
# Ejercicio 2.1: Count plot - Transacciones por ciudad
# TODO: Usa sns.countplot() para mostrar cantidad de transacciones por ciudad
# Pista:
# 1. sns.countplot(data=df, x='ciudad')
# 2. Ordena por frecuencia usando order=df['ciudad'].value_counts().index
# 3. Agrega palette='viridis' para colores

plt.figure(figsize=(10, 6))
# Tu código aquí


plt.title('Transacciones por Ciudad', fontsize=14, fontweight='bold')
plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Transacciones')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.2 Box Plot (Diagrama de Cajas)

# %%
# Ejercicio 2.2: Box plot - Distribución de montos por tipo de transacción
# TODO: Crea un box plot para comparar la distribución de montos entre tipos
# Pista:
# 1. sns.boxplot(data=df, x='tipo_transaccion', y='monto_absoluto')
# 2. Rota las etiquetas del eje x
# 3. Opcional: filtra montos < $3,000,000 para mejor escala

plt.figure(figsize=(12, 6))
# Tu código aquí


plt.title('Distribución de Montos por Tipo de Transacción', fontsize=14, fontweight='bold')
plt.xlabel('Tipo de Transacción')
plt.ylabel('Monto Absoluto ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3 Violin Plot

# %%
# Ejercicio 2.3: Violin plot - Distribución de montos por canal
# TODO: Crea un violin plot para ver distribución de montos por canal
# Pista:
# 1. sns.violinplot(data=df, x='canal', y='monto_absoluto')
# 2. Agrega inner='box' para mostrar el box plot interno
# 3. Filtra datos si es necesario para mejor visualización

plt.figure(figsize=(12, 6))
# Tu código aquí


plt.title('Distribución de Montos por Canal', fontsize=14, fontweight='bold')
plt.xlabel('Canal')
plt.ylabel('Monto Absoluto ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 Heatmap (Mapa de Calor)

# %%
# Ejercicio 2.4: Heatmap - Tabla cruzada Tipo vs Canal
# TODO: Crea un heatmap mostrando la cantidad de transacciones por tipo y canal
# Pista:
# 1. Crea tabla cruzada: pd.crosstab(df['tipo_transaccion'], df['canal'])
# 2. Usa sns.heatmap() con annot=True para mostrar valores
# 3. Agrega fmt='d' para formato entero y cmap='YlOrRd' para colores

# Tu código aquí
tabla_tipo_canal = 

plt.figure(figsize=(10, 6))
# Crear heatmap


plt.title('Cantidad de Transacciones: Tipo vs Canal', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.5 Pair Plot (Solo para muestra)

# %%
# Ejercicio 2.5: Pair plot - Relaciones entre variables numéricas
# TODO: Crea un pair plot para ver relaciones entre variables
# Pista:
# 1. Selecciona una muestra del dataset (sample(500)) para que no sea muy pesado
# 2. Selecciona columnas numéricas relevantes: ['monto_absoluto', 'hora_num', 'mes', 'dia_semana']
# 3. Usa sns.pairplot() con hue='tipo_transaccion'

# Tu código aquí
muestra = df.sample(500, random_state=42)

# Crear pair plot


plt.suptitle('Relaciones entre Variables Numéricas', y=1.02, fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## PARTE 3: ANÁLISIS TEMPORAL CON GRÁFICOS DE LÍNEA

# %% [markdown]
# ### 3.1 Evolución Mensual

# %%
# Ejercicio 3.1: Gráfico de línea - Cantidad de transacciones por mes
# TODO: Muestra la evolución mensual de transacciones
# Pista:
# 1. Agrupa por 'fecha' usando df.groupby(df['fecha'].dt.to_period('M')).size()
# 2. Convierte el índice a timestamp para graficar
# 3. Usa plt.plot() con marker='o' y linewidth=2

# Tu código aquí
transacciones_mes = 

plt.figure(figsize=(14, 6))
# Crear gráfico de línea


plt.title('Evolución Mensual de Transacciones', fontsize=14, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Transacciones')
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Múltiples Líneas

# %%
# Ejercicio 3.2: Gráfico de líneas múltiples - Evolución por tipo de transacción
# TODO: Muestra la evolución mensual separada por tipo de transacción
# Pista:
# 1. Agrupa por fecha (mes) y tipo_transaccion
# 2. Usa unstack() para crear columnas por tipo
# 3. Grafica con .plot(kind='line', marker='o')

# Tu código aquí
evolucion_tipo = df.groupby([df['fecha'].dt.to_period('M'), 'tipo_transaccion']).size().unstack(fill_value=0)
evolucion_tipo.index = evolucion_tipo.index.to_timestamp()

plt.figure(figsize=(14, 6))
# Crear gráfico de líneas múltiples


plt.title('Evolución Mensual por Tipo de Transacción', fontsize=14, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Transacciones')
plt.legend(title='Tipo', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Área Apilada (Stacked Area)

# %%
# Ejercicio 3.3: Gráfico de área apilada - Composición mensual por canal
# TODO: Muestra cómo se distribuyen los canales a lo largo del tiempo
# Pista:
# 1. Similar al ejercicio anterior pero agrupa por canal
# 2. Usa .plot(kind='area', stacked=True, alpha=0.7)

# Tu código aquí
evolucion_canal = 

plt.figure(figsize=(14, 6))
# Crear gráfico de área


plt.title('Composición Mensual de Transacciones por Canal', fontsize=14, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Cantidad de Transacciones')
plt.legend(title='Canal', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## PARTE 4: VISUALIZACIONES COMPARATIVAS

# %% [markdown]
# ### 4.1 Gráfico de Barras Agrupadas

# %%
# Ejercicio 4.1: Barras agrupadas - Estados por tipo de transacción
# TODO: Compara la cantidad de estados (Exitosa, Fallida, Pendiente) por tipo
# Pista:
# 1. Crea tabla cruzada: pd.crosstab(df['tipo_transaccion'], df['estado'])
# 2. Usa .plot(kind='bar') sin stacked

# Tu código aquí
estados_tipo = 

plt.figure(figsize=(12, 6))
# Crear gráfico de barras agrupadas


plt.title('Estado de Transacciones por Tipo', fontsize=14, fontweight='bold')
plt.xlabel('Tipo de Transacción')
plt.ylabel('Cantidad')
plt.legend(title='Estado')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Gráfico de Barras Apiladas

# %%
# Ejercicio 4.2: Barras apiladas - Rango de montos por ciudad
# TODO: Muestra cómo se distribuyen los rangos de monto en cada ciudad
# Pista:
# 1. Crea tabla cruzada: pd.crosstab(df['ciudad'], df['rango_monto'])
# 2. Usa .plot(kind='bar', stacked=True)

# Tu código aquí
rangos_ciudad = 

plt.figure(figsize=(10, 6))
# Crear gráfico de barras apiladas


plt.title('Distribución de Rangos de Monto por Ciudad', fontsize=14, fontweight='bold')
plt.xlabel('Ciudad')
plt.ylabel('Cantidad de Transacciones')
plt.legend(title='Rango de Monto', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3 Comparación con Barras Horizontales

# %%
# Ejercicio 4.3: Barras horizontales - Monto promedio por categoría
# TODO: Compara el monto promedio de cada categoría (solo gastos, monto < 0)
# Pista:
# 1. Filtra solo transacciones con monto negativo
# 2. Agrupa por categoría y calcula el promedio de monto_absoluto
# 3. Ordena de mayor a menor y usa .plot(kind='barh')

# Tu código aquí
gastos = df[df['monto'] < 0]


plt.title('Monto Promedio de Gasto por Categoría', fontsize=14, fontweight='bold')
plt.xlabel('Monto Promedio ($)')
plt.ylabel('Categoría')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.4 Swarm Plot

# %%
# Ejercicio 4.4: Swarm plot - Distribución de montos por trimestre
# TODO: Visualiza la distribución de montos (muestra) por trimestre
# Pista:
# 1. Toma una muestra de 500 registros
# 2. Filtra montos < $1,000,000 para mejor visualización
# 3. Usa sns.swarmplot(data=muestra, x='trimestre', y='monto_absoluto')

# Tu código aquí
muestra = 

plt.figure(figsize=(12, 6))
# Crear swarm plot


plt.title('Distribución de Montos por Trimestre (muestra)', fontsize=14, fontweight='bold')
plt.xlabel('Trimestre')
plt.ylabel('Monto Absoluto ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## PARTE 5: ANÁLISIS ESPECÍFICO DEL NEGOCIO

# %% [markdown]
# ### 5.1 Análisis de Transacciones Sospechosas

# %%
# Ejercicio 5.1: Comparación de transacciones normales vs sospechosas
# TODO: Crea un gráfico que compare la distribución de montos entre normales y sospechosas
# Pista:
# 1. Separa en dos dataframes según 'sospechosa'
# 2. Usa plt.hist() con alpha=0.6 para transparencia
# 3. Grafica ambas distribuciones en el mismo plot con diferentes colores

# Tu código aquí
normales = df[df['sospechosa'] == False]['monto_absoluto']
sospechosas = df[df['sospechosa'] == True]['monto_absoluto']

plt.figure(figsize=(12, 6))
# Crear histogramas superpuestos


plt.title('Comparación de Distribución de Montos: Normales vs Sospechosas', fontsize=14, fontweight='bold')
plt.xlabel('Monto Absoluto ($)')
plt.ylabel('Frecuencia')
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Análisis de Patrones Horarios

# %%
# Ejercicio 5.2: Heatmap de actividad por hora y día de semana
# TODO: Crea un heatmap mostrando cuándo hay más transacciones
# Pista:
# 1. Crea tabla pivote: df.pivot_table(values='id_transaccion', index='hora_num', columns='dia_semana', aggfunc='count')
# 2. Usa sns.heatmap() con cmap='YlGnBu'
# 3. Personaliza las etiquetas del eje y (días de semana)

# Tu código aquí
actividad_horaria = 

# Cambiar nombres de columnas a días
dias = ['Lun', 'Mar', 'Mié', 'Jue', 'Vie', 'Sáb', 'Dom']
actividad_horaria.columns = [dias[int(col)] for col in actividad_horaria.columns]

plt.figure(figsize=(12, 10))
# Crear heatmap


plt.title('Actividad de Transacciones por Hora y Día de la Semana', fontsize=14, fontweight='bold')
plt.xlabel('Día de la Semana')
plt.ylabel('Hora del Día')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Top Categorías por Ciudad

# %%
# Ejercicio 5.3: Gráfico de barras agrupadas - Top 5 categorías por ciudad
# TODO: Muestra las 5 categorías más usadas en cada ciudad
# Pista:
# 1. Crea tabla cruzada de ciudad y categoria
# 2. Selecciona las top 5 categorías globales
# 3. Crea un subplot para cada ciudad

# Tu código aquí
ciudad_categoria = pd.crosstab(df['ciudad'], df['categoria'])
top_categorias = df['categoria'].value_counts().head(5).index

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

ciudades = df['ciudad'].unique()
for i, ciudad in enumerate(ciudades):
    # Graficar para cada ciudad
    pass

# Eliminar subplot extra si hay
if len(ciudades) < len(axes):
    fig.delaxes(axes[-1])

plt.suptitle('Top 5 Categorías por Ciudad', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## PARTE 6: DASHBOARD FINAL (MÚLTIPLES GRÁFICOS)

# %%
# Ejercicio 6.1: Dashboard completo con múltiples visualizaciones
# TODO: Crea un dashboard con 6 gráficos diferentes en una sola figura
# Pista:
# 1. Usa plt.subplots(3, 2, figsize=(16, 14))
# 2. Grafica en cada subplot (axes[row, col]) usando plot(), bar(), hist(), etc.
# 3. Incluye: transacciones por tipo, evolución temporal, distribución montos,
#    estados, canales, y un gráfico libre

fig, axes = plt.subplots(3, 2, figsize=(16, 14))

# Gráfico 1: Transacciones por Tipo (barras)
# TODO: Completa este gráfico
transacciones_tipo = df['tipo_transaccion'].value_counts()
axes[0, 0].bar(transacciones_tipo.index, transacciones_tipo.values)
axes[0, 0].set_title('Transacciones por Tipo', fontweight='bold')
axes[0, 0].set_xlabel('Tipo')
axes[0, 0].set_ylabel('Cantidad')
axes[0, 0].tick_params(axis='x', rotation=45)

# Gráfico 2: Evolución Mensual (línea)
# TODO: Completa este gráfico


# Gráfico 3: Distribución de Montos (histograma)
# TODO: Completa este gráfico


# Gráfico 4: Estados (pastel)
# TODO: Completa este gráfico


# Gráfico 5: Canales (barras horizontales)
# TODO: Completa este gráfico


# Gráfico 6: Libre (elige el que quieras)
# TODO: Completa este gráfico


plt.suptitle('Dashboard de Análisis de Transacciones Bancarias', 
             fontsize=18, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## BONUS: PERSONALIZACIÓN AVANZADA

# %%
# Ejercicio BONUS 1: Gráfico con anotaciones y personalización avanzada
# TODO: Crea un gráfico de barras del monto total por ciudad con:
# - Etiquetas de valor en cada barra
# - Colores diferentes por barra
# - Grid personalizado
# - Título y subtítulo

# Tu código aquí
monto_ciudad = df.groupby('ciudad')['monto_absoluto'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
# Crear gráfico con personalización avanzada
bars = plt.bar(monto_ciudad.index, monto_ciudad.values / 1_000_000, 
               color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8'])

# Agregar etiquetas de valor en cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'${height:.1f}M',
             ha='center', va='bottom', fontweight='bold')

plt.title('Volumen Total de Transacciones por Ciudad', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Ciudad', fontsize=12)
plt.ylabel('Monto Total (Millones $)', fontsize=12)
plt.grid(axis='y', alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

# %%
# Ejercicio BONUS 2: Gráfico de dispersión con regresión lineal
# TODO: Crea un scatter plot de mes vs monto promedio con línea de tendencia
# Pista:
# 1. Agrupa por mes y calcula el promedio
# 2. Usa sns.regplot() para agregar la línea de tendencia

# Tu código aquí


plt.title('Tendencia del Monto Promedio por Mes', fontsize=14, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Monto Promedio ($)')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## FIN DEL TALLER
#
# ### Conceptos Aplicados:
# #### Matplotlib:
# - ✅ Gráficos de barras (verticales y horizontales)
# - ✅ Gráficos de pastel
# - ✅ Histogramas
# - ✅ Scatter plots
# - ✅ Gráficos de línea (simple y múltiple)
# - ✅ Gráficos de área
# - ✅ Subplots y dashboards
# - ✅ Personalización (títulos, etiquetas, colores, grid)
#
# #### Seaborn:
# - ✅ Count plots
# - ✅ Box plots
# - ✅ Violin plots
# - ✅ Heatmaps
# - ✅ Pair plots
# - ✅ Swarm plots
# - ✅ Regresión lineal
#
# #### Análisis de Negocio:
# - ✅ Análisis temporal
# - ✅ Comparaciones categóricas
# - ✅ Detección de patrones
# - ✅ Identificación de anomalías
# - ✅ Distribuciones estadísticas
#
# ### ¡Felicitaciones! 🎉
# Has completado el taller de visualización. Ahora tienes las herramientas para:
# - Crear visualizaciones profesionales
# - Comunicar insights de datos efectivamente
# - Detectar patrones y anomalías visualmente
# - Construir dashboards completos
